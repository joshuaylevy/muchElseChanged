# %%
#Preamble and packages
import pandas as pd
import requests
from bs4 import BeautifulSoup
from functools import partial
print("Script is running, please be patient")
# Out:
# Script is running, please be patient

# %%
base_url = "https://www.nfl.com/standings/division/" 
# initialize empty pandas dataframe, to which each team-year observation is added
teamRecorddf = pd.DataFrame()

# %%
for year in range(2000,2021):
    yeardf = pd.DataFrame()
    print("Scraping year: " + str(year))
    #create unique URL for each year's results page
    url = base_url + str(year) + "/REG"
    print(url)
    #load page html
    page = requests.get(url)
    #Parse html to be readable - This script uses the html parser which is slower than lxml's parser but does not require additional dependencies or installs
    soup = BeautifulSoup(page.content, 'html.parser')

    #Go to the table
    table = soup.find(class_='d3-o-table')
    table_head = table.find('thead').find('tr').find_all('th')
    
    #collect column headers
    df_headers = []
    for header in table_head:
        col = header.string.strip()
        df_headers.append(col) 

    #Change the stand-in conference header to be the correct column title "Team" and changing second "Pct" so as to remove duplicate column titles
    df_headers[0] = 'Team'
    df_headers[4] = 'Pct_total'
    df_headers[11] = 'Pct_div'
    df_headers[13] = 'Pct_conf'




    # Each conference has a separate table (but all have the same headings)
    tables = soup.find_all(class_='d3-o-table')
    for conf in tables:
        confdf = pd.DataFrame()
        #find rows
        table_body = conf.find('tbody')
        table_rows = table_body.find_all('tr')
        #scrape each column for values
        for row in table_rows:
            team_values = []
            cols = row.find_all('td')

            i = 1    
            for col in cols:

                if i == 1:
                    # team_box = col.find(class_='d3-club-info')
                    team_name = col.find(class_='d3-o-club-shortname').contents[0].strip()
                    print("currently scraping: " + team_name)
                    team_values.append(team_name)
                    i = i+1
                else:
                    col_value = col.string.strip()
                    team_values.append(col_value)
                    i = i+1
                    
            team_values = [team_values]
            teamdf = pd.DataFrame(
                team_values,
                columns=df_headers
            )
            teamdf['year'] = year
            
            confdf = pd.concat([confdf, teamdf], ignore_index=True)
            

        yeardf = pd.concat([yeardf,confdf], ignore_index=True)
        
    teamRecorddf = pd.concat([teamRecorddf,yeardf], ignore_index=True)
# Out:
# Scraping year: 2000
# https://www.nfl.com/standings/division/2000/REG
# currently scraping: Cardinals
# currently scraping: Cowboys
# currently scraping: Washington
# currently scraping: Eagles
# currently scraping: Falcons
# currently scraping: 49ers
# currently scraping: Panthers
# currently scraping: Rams
# currently scraping: Saints
# currently scraping: Bears
# currently scraping: Lions
# currently scraping: Buccaneers
# currently scraping: Packers
# currently scraping: Vikings
# currently scraping: Chargers
# currently scraping: Seahawks
# currently scraping: Chiefs
# currently scraping: Broncos
# currently scraping: Raiders
# currently scraping: Browns
# currently scraping: Bengals
# currently scraping: Jaguars
# currently scraping: Steelers
# currently scraping: Titans
# currently scraping: Ravens
# currently scraping: Patriots
# currently scraping: Bills
# currently scraping: Jets
# currently scraping: Colts
# currently scraping: Dolphins
# Scraping year: 2001
# https://www.nfl.com/standings/division/2001/REG
# currently scraping: Cardinals
# currently scraping: Cowboys
# currently scraping: Giants
# currently scraping: Washington
# currently scraping: Panthers
# currently scraping: Saints
# currently scraping: Falcons
# currently scraping: 49ers
# currently scraping: Rams
# currently scraping: Lions
# currently scraping: Vikings
# currently scraping: Buccaneers
# currently scraping: Packers
# currently scraping: Bears
# currently scraping: Bills
# currently scraping: Colts
# currently scraping: Jets
# currently scraping: Patriots
# currently scraping: Dolphins
# currently scraping: Chargers
# currently scraping: Chiefs
# currently scraping: Broncos
# currently scraping: Raiders
# currently scraping: Seahawks
# currently scraping: Titans
# currently scraping: Bengals
# currently scraping: Jaguars
# currently scraping: Browns
# currently scraping: Ravens
# currently scraping: Steelers
# Scraping year: 2002
# https://www.nfl.com/standings/division/2002/REG
# currently scraping: Cardinals
# currently scraping: Rams
# currently scraping: Seahawks
# currently scraping: 49ers
# currently scraping: Lions
# currently scraping: Bears
# currently scraping: Vikings
# currently scraping: Packers
# currently scraping: Cowboys
# currently scraping: Washington
# currently scraping: Giants
# currently scraping: Eagles
# currently scraping: Panthers
# currently scraping: Falcons
# currently scraping: Saints
# currently scraping: Buccaneers
# currently scraping: Bengals
# currently scraping: Ravens
# currently scraping: Browns
# currently scraping: Steelers
# currently scraping: Texans
# currently scraping: Jaguars
# currently scraping: Colts
# currently scraping: Titans
# currently scraping: Bills
# currently scraping: Patriots
# currently scraping: Jets
# currently scraping: Dolphins
# currently scraping: Broncos
# currently scraping: Chiefs
# currently scraping: Chargers
# currently scraping: Raiders
# Scraping year: 2003
# https://www.nfl.com/standings/division/2003/REG
# currently scraping: Cardinals
# currently scraping: 49ers
# currently scraping: Seahawks
# currently scraping: Rams
# currently scraping: Giants
# currently scraping: Washington
# currently scraping: Cowboys
# currently scraping: Eagles
# currently scraping: Falcons
# currently scraping: Buccaneers
# currently scraping: Saints
# currently scraping: Panthers
# currently scraping: Lions
# currently scraping: Bears
# currently scraping: Vikings
# currently scraping: Packers
# currently scraping: Chargers
# currently scraping: Raiders
# currently scraping: Broncos
# currently scraping: Chiefs
# currently scraping: Browns
# currently scraping: Steelers
# currently scraping: Bengals
# currently scraping: Ravens
# currently scraping: Texans
# currently scraping: Jaguars
# currently scraping: Titans
# currently scraping: Colts
# currently scraping: Bills
# currently scraping: Jets
# currently scraping: Dolphins
# currently scraping: Patriots
# Scraping year: 2004
# https://www.nfl.com/standings/division/2004/REG
# currently scraping: 49ers
# currently scraping: Cardinals
# currently scraping: Rams
# currently scraping: Seahawks
# currently scraping: Bears
# currently scraping: Lions
# currently scraping: Vikings
# currently scraping: Packers
# currently scraping: Buccaneers
# currently scraping: Panthers
# currently scraping: Saints
# currently scraping: Falcons
# currently scraping: Cowboys
# currently scraping: Giants
# currently scraping: Washington
# currently scraping: Eagles
# currently scraping: Dolphins
# currently scraping: Bills
# currently scraping: Jets
# currently scraping: Patriots
# currently scraping: Browns
# currently scraping: Bengals
# currently scraping: Ravens
# currently scraping: Steelers
# currently scraping: Raiders
# currently scraping: Chiefs
# currently scraping: Broncos
# currently scraping: Chargers
# currently scraping: Titans
# currently scraping: Texans
# currently scraping: Jaguars
# currently scraping: Colts
# Scraping year: 2005
# https://www.nfl.com/standings/division/2005/REG
# currently scraping: 49ers
# currently scraping: Rams
# currently scraping: Cardinals
# currently scraping: Seahawks
# currently scraping: Saints
# currently scraping: Falcons
# currently scraping: Panthers
# currently scraping: Buccaneers
# currently scraping: Lions
# currently scraping: Packers
# currently scraping: Vikings
# currently scraping: Bears
# currently scraping: Eagles
# currently scraping: Cowboys
# currently scraping: Giants
# currently scraping: Washington
# currently scraping: Texans
# currently scraping: Titans
# currently scraping: Jaguars
# currently scraping: Colts
# currently scraping: Raiders
# currently scraping: Chargers
# currently scraping: Chiefs
# currently scraping: Broncos
# currently scraping: Jets
# currently scraping: Bills
# currently scraping: Dolphins
# currently scraping: Patriots
# currently scraping: Ravens
# currently scraping: Browns
# currently scraping: Bengals
# currently scraping: Steelers
# Scraping year: 2006
# https://www.nfl.com/standings/division/2006/REG
# currently scraping: Cardinals
# currently scraping: 49ers
# currently scraping: Rams
# currently scraping: Seahawks
# currently scraping: Lions
# currently scraping: Vikings
# currently scraping: Packers
# currently scraping: Bears
# currently scraping: Buccaneers
# currently scraping: Falcons
# currently scraping: Panthers
# currently scraping: Saints
# currently scraping: Washington
# currently scraping: Cowboys
# currently scraping: Giants
# currently scraping: Eagles
# currently scraping: Raiders
# currently scraping: Chiefs
# currently scraping: Broncos
# currently scraping: Chargers
# currently scraping: Browns
# currently scraping: Steelers
# currently scraping: Bengals
# currently scraping: Ravens
# currently scraping: Dolphins
# currently scraping: Bills
# currently scraping: Jets
# currently scraping: Patriots
# currently scraping: Jaguars
# currently scraping: Titans
# currently scraping: Texans
# currently scraping: Colts
# Scraping year: 2007
# https://www.nfl.com/standings/division/2007/REG
# currently scraping: Seahawks
# currently scraping: Cardinals
# currently scraping: 49ers
# currently scraping: Rams
# currently scraping: Buccaneers
# currently scraping: Panthers
# currently scraping: Saints
# currently scraping: Falcons
# currently scraping: Packers
# currently scraping: Vikings
# currently scraping: Lions
# currently scraping: Bears
# currently scraping: Cowboys
# currently scraping: Giants
# currently scraping: Washington
# currently scraping: Eagles
# currently scraping: Patriots
# currently scraping: Bills
# currently scraping: Jets
# currently scraping: Dolphins
# currently scraping: Steelers
# currently scraping: Browns
# currently scraping: Bengals
# currently scraping: Ravens
# currently scraping: Chargers
# currently scraping: Broncos
# currently scraping: Chiefs
# currently scraping: Raiders
# currently scraping: Colts
# currently scraping: Jaguars
# currently scraping: Titans
# currently scraping: Texans
# Scraping year: 2008
# https://www.nfl.com/standings/division/2008/REG
# currently scraping: Cardinals
# currently scraping: 49ers
# currently scraping: Seahawks
# currently scraping: Rams
# currently scraping: Vikings
# currently scraping: Bears
# currently scraping: Packers
# currently scraping: Lions
# currently scraping: Panthers
# currently scraping: Falcons
# currently scraping: Buccaneers
# currently scraping: Saints
# currently scraping: Giants
# currently scraping: Eagles
# currently scraping: Cowboys
# currently scraping: Washington
# currently scraping: Chargers
# currently scraping: Broncos
# currently scraping: Raiders
# currently scraping: Chiefs
# currently scraping: Steelers
# currently scraping: Ravens
# currently scraping: Bengals
# currently scraping: Browns
# currently scraping: Titans
# currently scraping: Colts
# currently scraping: Texans
# currently scraping: Jaguars
# currently scraping: Dolphins
# currently scraping: Patriots
# currently scraping: Jets
# currently scraping: Bills
# Scraping year: 2009
# https://www.nfl.com/standings/division/2009/REG
# currently scraping: Cardinals
# currently scraping: 49ers
# currently scraping: Seahawks
# currently scraping: Rams
# currently scraping: Vikings
# currently scraping: Packers
# currently scraping: Bears
# currently scraping: Lions
# currently scraping: Cowboys
# currently scraping: Eagles
# currently scraping: Giants
# currently scraping: Washington
# currently scraping: Saints
# currently scraping: Falcons
# currently scraping: Panthers
# currently scraping: Buccaneers
# currently scraping: Chargers
# currently scraping: Broncos
# currently scraping: Raiders
# currently scraping: Chiefs
# currently scraping: Patriots
# currently scraping: Jets
# currently scraping: Dolphins
# currently scraping: Bills
# currently scraping: Colts
# currently scraping: Texans
# currently scraping: Titans
# currently scraping: Jaguars
# currently scraping: Bengals
# currently scraping: Ravens
# currently scraping: Steelers
# currently scraping: Browns
# Scraping year: 2010
# https://www.nfl.com/standings/division/2010/REG
# currently scraping: Bears
# currently scraping: Packers
# currently scraping: Lions
# currently scraping: Vikings
# currently scraping: Falcons
# currently scraping: Saints
# currently scraping: Buccaneers
# currently scraping: Panthers
# currently scraping: Seahawks
# currently scraping: Rams
# currently scraping: 49ers
# currently scraping: Cardinals
# currently scraping: Eagles
# currently scraping: Giants
# currently scraping: Cowboys
# currently scraping: Washington
# currently scraping: Patriots
# currently scraping: Jets
# currently scraping: Dolphins
# currently scraping: Bills
# currently scraping: Steelers
# currently scraping: Ravens
# currently scraping: Browns
# currently scraping: Bengals
# currently scraping: Chiefs
# currently scraping: Chargers
# currently scraping: Raiders
# currently scraping: Broncos
# currently scraping: Colts
# currently scraping: Jaguars
# currently scraping: Texans
# currently scraping: Titans
# Scraping year: 2011
# https://www.nfl.com/standings/division/2011/REG
# currently scraping: Ravens
# currently scraping: Steelers
# currently scraping: Bengals
# currently scraping: Browns
# currently scraping: Texans
# currently scraping: Titans
# currently scraping: Jaguars
# currently scraping: Colts
# currently scraping: Patriots
# currently scraping: Jets
# currently scraping: Dolphins
# currently scraping: Bills
# currently scraping: Broncos
# currently scraping: Chargers
# currently scraping: Raiders
# currently scraping: Chiefs
# currently scraping: 49ers
# currently scraping: Cardinals
# currently scraping: Seahawks
# currently scraping: Rams
# currently scraping: Packers
# currently scraping: Lions
# currently scraping: Bears
# currently scraping: Vikings
# currently scraping: Saints
# currently scraping: Falcons
# currently scraping: Panthers
# currently scraping: Buccaneers
# currently scraping: Giants
# currently scraping: Eagles
# currently scraping: Cowboys
# currently scraping: Washington
# Scraping year: 2012
# https://www.nfl.com/standings/division/2012/REG
# currently scraping: Washington
# currently scraping: Giants
# currently scraping: Cowboys
# currently scraping: Eagles
# currently scraping: Packers
# currently scraping: Vikings
# currently scraping: Bears
# currently scraping: Lions
# currently scraping: 49ers
# currently scraping: Seahawks
# currently scraping: Rams
# currently scraping: Cardinals
# currently scraping: Falcons
# currently scraping: Panthers
# currently scraping: Saints
# currently scraping: Buccaneers
# currently scraping: Broncos
# currently scraping: Chargers
# currently scraping: Raiders
# currently scraping: Chiefs
# currently scraping: Texans
# currently scraping: Colts
# currently scraping: Titans
# currently scraping: Jaguars
# currently scraping: Patriots
# currently scraping: Dolphins
# currently scraping: Jets
# currently scraping: Bills
# currently scraping: Ravens
# currently scraping: Bengals
# currently scraping: Steelers
# currently scraping: Browns
# Scraping year: 2013
# https://www.nfl.com/standings/division/2013/REG
# currently scraping: Seahawks
# currently scraping: 49ers
# currently scraping: Cardinals
# currently scraping: Rams
# currently scraping: Eagles
# currently scraping: Cowboys
# currently scraping: Giants
# currently scraping: Washington
# currently scraping: Panthers
# currently scraping: Saints
# currently scraping: Falcons
# currently scraping: Buccaneers
# currently scraping: Packers
# currently scraping: Bears
# currently scraping: Lions
# currently scraping: Vikings
# currently scraping: Colts
# currently scraping: Titans
# currently scraping: Jaguars
# currently scraping: Texans
# currently scraping: Bengals
# currently scraping: Steelers
# currently scraping: Ravens
# currently scraping: Browns
# currently scraping: Broncos
# currently scraping: Chiefs
# currently scraping: Chargers
# currently scraping: Raiders
# currently scraping: Patriots
# currently scraping: Jets
# currently scraping: Dolphins
# currently scraping: Bills
# Scraping year: 2014
# https://www.nfl.com/standings/division/2014/REG
# currently scraping: Cowboys
# currently scraping: Eagles
# currently scraping: Giants
# currently scraping: Washington
# currently scraping: Panthers
# currently scraping: Saints
# currently scraping: Falcons
# currently scraping: Buccaneers
# currently scraping: Packers
# currently scraping: Lions
# currently scraping: Vikings
# currently scraping: Bears
# currently scraping: Seahawks
# currently scraping: Cardinals
# currently scraping: 49ers
# currently scraping: Rams
# currently scraping: Colts
# currently scraping: Texans
# currently scraping: Jaguars
# currently scraping: Titans
# currently scraping: Broncos
# currently scraping: Chiefs
# currently scraping: Chargers
# currently scraping: Raiders
# currently scraping: Patriots
# currently scraping: Bills
# currently scraping: Dolphins
# currently scraping: Jets
# currently scraping: Steelers
# currently scraping: Bengals
# currently scraping: Ravens
# currently scraping: Browns
# Scraping year: 2015
# https://www.nfl.com/standings/division/2015/REG
# currently scraping: Cardinals
# currently scraping: Seahawks
# currently scraping: Rams
# currently scraping: 49ers
# currently scraping: Washington
# currently scraping: Eagles
# currently scraping: Giants
# currently scraping: Cowboys
# currently scraping: Vikings
# currently scraping: Packers
# currently scraping: Lions
# currently scraping: Bears
# currently scraping: Panthers
# currently scraping: Falcons
# currently scraping: Saints
# currently scraping: Buccaneers
# currently scraping: Texans
# currently scraping: Colts
# currently scraping: Jaguars
# currently scraping: Titans
# currently scraping: Bengals
# currently scraping: Steelers
# currently scraping: Ravens
# currently scraping: Browns
# currently scraping: Broncos
# currently scraping: Chiefs
# currently scraping: Raiders
# currently scraping: Chargers
# currently scraping: Patriots
# currently scraping: Jets
# currently scraping: Bills
# currently scraping: Dolphins
# Scraping year: 2016
# https://www.nfl.com/standings/division/2016/REG
# currently scraping: Seahawks
# currently scraping: Cardinals
# currently scraping: Rams
# currently scraping: 49ers
# currently scraping: Packers
# currently scraping: Lions
# currently scraping: Vikings
# currently scraping: Bears
# currently scraping: Falcons
# currently scraping: Buccaneers
# currently scraping: Saints
# currently scraping: Panthers
# currently scraping: Cowboys
# currently scraping: Giants
# currently scraping: Washington
# currently scraping: Eagles
# currently scraping: Steelers
# currently scraping: Ravens
# currently scraping: Bengals
# currently scraping: Browns
# currently scraping: Texans
# currently scraping: Titans
# currently scraping: Colts
# currently scraping: Jaguars
# currently scraping: Patriots
# currently scraping: Dolphins
# currently scraping: Bills
# currently scraping: Jets
# currently scraping: Chiefs
# currently scraping: Raiders
# currently scraping: Broncos
# currently scraping: Chargers
# Scraping year: 2017
# https://www.nfl.com/standings/division/2017/REG
# currently scraping: Rams
# currently scraping: Seahawks
# currently scraping: Cardinals
# currently scraping: 49ers
# currently scraping: Eagles
# currently scraping: Cowboys
# currently scraping: Washington
# currently scraping: Giants
# currently scraping: Vikings
# currently scraping: Lions
# currently scraping: Packers
# currently scraping: Bears
# currently scraping: Saints
# currently scraping: Panthers
# currently scraping: Falcons
# currently scraping: Buccaneers
# currently scraping: Steelers
# currently scraping: Ravens
# currently scraping: Bengals
# currently scraping: Browns
# currently scraping: Jaguars
# currently scraping: Titans
# currently scraping: Colts
# currently scraping: Texans
# currently scraping: Chiefs
# currently scraping: Chargers
# currently scraping: Raiders
# currently scraping: Broncos
# currently scraping: Patriots
# currently scraping: Bills
# currently scraping: Dolphins
# currently scraping: Jets
# Scraping year: 2018
# https://www.nfl.com/standings/division/2018/REG
# currently scraping: Rams
# currently scraping: Seahawks
# currently scraping: 49ers
# currently scraping: Cardinals
# currently scraping: Bears
# currently scraping: Vikings
# currently scraping: Packers
# currently scraping: Lions
# currently scraping: Cowboys
# currently scraping: Eagles
# currently scraping: Washington
# currently scraping: Giants
# currently scraping: Saints
# currently scraping: Falcons
# currently scraping: Panthers
# currently scraping: Buccaneers
# currently scraping: Patriots
# currently scraping: Dolphins
# currently scraping: Bills
# currently scraping: Jets
# currently scraping: Chiefs
# currently scraping: Chargers
# currently scraping: Broncos
# currently scraping: Raiders
# currently scraping: Texans
# currently scraping: Colts
# currently scraping: Titans
# currently scraping: Jaguars
# currently scraping: Ravens
# currently scraping: Steelers
# currently scraping: Browns
# currently scraping: Bengals
# Scraping year: 2019
# https://www.nfl.com/standings/division/2019/REG
# currently scraping: 49ers
# currently scraping: Seahawks
# currently scraping: Rams
# currently scraping: Cardinals
# currently scraping: Packers
# currently scraping: Vikings
# currently scraping: Bears
# currently scraping: Lions
# currently scraping: Eagles
# currently scraping: Cowboys
# currently scraping: Giants
# currently scraping: Washington
# currently scraping: Saints
# currently scraping: Falcons
# currently scraping: Buccaneers
# currently scraping: Panthers
# currently scraping: Ravens
# currently scraping: Steelers
# currently scraping: Browns
# currently scraping: Bengals
# currently scraping: Chiefs
# currently scraping: Broncos
# currently scraping: Raiders
# currently scraping: Chargers
# currently scraping: Patriots
# currently scraping: Bills
# currently scraping: Jets
# currently scraping: Dolphins
# currently scraping: Texans
# currently scraping: Titans
# currently scraping: Colts
# currently scraping: Jaguars
# Scraping year: 2020
# https://www.nfl.com/standings/division/2020/REG
# currently scraping: Seahawks
# currently scraping: Rams
# currently scraping: Cardinals
# currently scraping: 49ers
# currently scraping: Saints
# currently scraping: Buccaneers
# currently scraping: Panthers
# currently scraping: Falcons
# currently scraping: Washington
# currently scraping: Giants
# currently scraping: Cowboys
# currently scraping: Eagles
# currently scraping: Packers
# currently scraping: Bears
# currently scraping: Vikings
# currently scraping: Lions
# currently scraping: Titans
# currently scraping: Colts
# currently scraping: Texans
# currently scraping: Jaguars
# currently scraping: Bills
# currently scraping: Dolphins
# currently scraping: Patriots
# currently scraping: Jets
# currently scraping: Steelers
# currently scraping: Ravens
# currently scraping: Browns
# currently scraping: Bengals
# currently scraping: Chiefs
# currently scraping: Raiders
# currently scraping: Chargers
# currently scraping: Broncos

# %%
yeardf
# Out:
#           Team   W   L  T Pct_total   PF   PA Net Pts       Home       Road  \
# 0     Seahawks  12   4  0     0.750  459  371      88  7 - 1 - 0  5 - 3 - 0
# 1         Rams  10   6  0     0.625  372  296      76  6 - 2 - 0  4 - 4 - 0
# 2    Cardinals   8   8  0     0.500  410  367      43  4 - 4 - 0  4 - 4 - 0
# 3        49ers   6  10  0     0.375  376  390     -14  1 - 7 - 0  5 - 3 - 0
# 4       Saints  12   4  0     0.750  482  337     145  6 - 2 - 0  6 - 2 - 0
# 5   Buccaneers  11   5  0     0.688  492  355     137  5 - 3 - 0  6 - 2 - 0
# 6     Panthers   5  11  0     0.313  350  402     -52  2 - 6 - 0  3 - 5 - 0
# 7      Falcons   4  12  0     0.250  396  414     -18  2 - 6 - 0  2 - 6 - 0
# 8   Washington   7   9  0     0.438  335  329       6  3 - 5 - 0  4 - 4 - 0
# 9       Giants   6  10  0     0.375  280  357     -77  3 - 5 - 0  3 - 5 - 0
# 10     Cowboys   6  10  0     0.375  395  473     -78  4 - 4 - 0  2 - 6 - 0
# 11      Eagles   4  11  1     0.281  334  418     -84  3 - 4 - 1  1 - 7 - 0
# 12     Packers  13   3  0     0.813  509  369     140  7 - 1 - 0  6 - 2 - 0
# 13       Bears   8   8  0     0.500  372  370       2  3 - 5 - 0  5 - 3 - 0
# 14     Vikings   7   9  0     0.438  430  475     -45  3 - 5 - 0  4 - 4 - 0
# 15       Lions   5  11  0     0.313  377  519    -142  1 - 7 - 0  4 - 4 - 0
# 16      Titans  11   5  0     0.688  491  439      52  5 - 3 - 0  6 - 2 - 0
# 17       Colts  11   5  0     0.688  451  362      89  6 - 2 - 0  5 - 3 - 0
# 18      Texans   4  12  0     0.250  384  464     -80  2 - 6 - 0  2 - 6 - 0
# 19     Jaguars   1  15  0     0.063  306  492    -186  1 - 7 - 0  0 - 8 - 0
# 20       Bills  13   3  0     0.813  501  375     126  7 - 1 - 0  6 - 2 - 0
# 21    Dolphins  10   6  0     0.625  404  338      66  5 - 3 - 0  5 - 3 - 0
# 22    Patriots   7   9  0     0.438  326  353     -27  5 - 3 - 0  2 - 6 - 0
# 23        Jets   2  14  0     0.125  243  457    -214  1 - 7 - 0  1 - 7 - 0
# 24    Steelers  12   4  0     0.750  416  312     104  7 - 1 - 0  5 - 3 - 0
# 25      Ravens  11   5  0     0.688  468  303     165  5 - 3 - 0  6 - 2 - 0
# 26      Browns  11   5  0     0.688  408  419     -11  6 - 2 - 0  5 - 3 - 0
# 27     Bengals   4  11  1     0.281  311  424    -113  3 - 5 - 0  1 - 6 - 1
# 28      Chiefs  14   2  0     0.875  473  362     111  6 - 2 - 0  8 - 0 - 0
# 29     Raiders   8   8  0     0.500  434  478     -44  2 - 6 - 0  6 - 2 - 0
# 30    Chargers   7   9  0     0.438  384  426     -42  4 - 4 - 0  3 - 5 - 0
# 31     Broncos   5  11  0     0.313  323  446    -123  2 - 6 - 0  3 - 5 - 0
#
#           Div Pct_div        Conf Pct_conf   Non-Conf Strk     Last 5  year
# 0   4 - 2 - 0   0.667   9 - 3 - 0    0.750  3 - 1 - 0   4W  4 - 1 - 0  2020
# 1   3 - 3 - 0   0.500   9 - 3 - 0    0.750  1 - 3 - 0   1W  3 - 2 - 0  2020
# 2   2 - 4 - 0   0.333   6 - 6 - 0    0.500  2 - 2 - 0   2L  2 - 3 - 0  2020
# 3   3 - 3 - 0   0.500   4 - 8 - 0    0.333  2 - 2 - 0   1L  1 - 4 - 0  2020
# 4   6 - 0 - 0   1.000  10 - 2 - 0    0.833  2 - 2 - 0   2W  3 - 2 - 0  2020
# 5   4 - 2 - 0   0.667   8 - 4 - 0    0.667  3 - 1 - 0   4W  4 - 1 - 0  2020
# 6   1 - 5 - 0   0.167   4 - 8 - 0    0.333  1 - 3 - 0   1L  1 - 4 - 0  2020
# 7   1 - 5 - 0   0.167  2 - 10 - 0    0.167  2 - 2 - 0   5L  0 - 5 - 0  2020
# 8   4 - 2 - 0   0.667   5 - 7 - 0    0.417  2 - 2 - 0   1W  3 - 2 - 0  2020
# 9   4 - 2 - 0   0.667   5 - 7 - 0    0.417  1 - 3 - 0   1W  2 - 3 - 0  2020
# 10  2 - 4 - 0   0.333   5 - 7 - 0    0.417  1 - 3 - 0   1L  3 - 2 - 0  2020
# 11  2 - 4 - 0   0.333   4 - 8 - 0    0.333  0 - 3 - 1   3L  1 - 4 - 0  2020
# 12  5 - 1 - 0   0.833  10 - 2 - 0    0.833  3 - 1 - 0   6W  5 - 0 - 0  2020
# 13  2 - 4 - 0   0.333   6 - 6 - 0    0.500  2 - 2 - 0   1L  3 - 2 - 0  2020
# 14  4 - 2 - 0   0.667   5 - 7 - 0    0.417  2 - 2 - 0   1W  2 - 3 - 0  2020
# 15  1 - 5 - 0   0.167   4 - 8 - 0    0.333  1 - 3 - 0   4L  1 - 4 - 0  2020
# 16  5 - 1 - 0   0.833   8 - 4 - 0    0.667  3 - 1 - 0   1W  3 - 2 - 0  2020
# 17  4 - 2 - 0   0.667   7 - 5 - 0    0.583  4 - 0 - 0   1W  4 - 1 - 0  2020
# 18  2 - 4 - 0   0.333   3 - 9 - 0    0.250  1 - 3 - 0   5L  0 - 5 - 0  2020
# 19  1 - 5 - 0   0.167  1 - 11 - 0    0.083  0 - 4 - 0  15L  0 - 5 - 0  2020
# 20  6 - 0 - 0   1.000  10 - 2 - 0    0.833  3 - 1 - 0   6W  5 - 0 - 0  2020
# 21  3 - 3 - 0   0.500   7 - 5 - 0    0.583  3 - 1 - 0   1L  3 - 2 - 0  2020
# 22  3 - 3 - 0   0.500   6 - 6 - 0    0.500  1 - 3 - 0   1W  2 - 3 - 0  2020
# 23  0 - 6 - 0   0.000  1 - 11 - 0    0.083  1 - 3 - 0   1L  2 - 3 - 0  2020
# 24  4 - 2 - 0   0.667   9 - 3 - 0    0.750  3 - 1 - 0   1L  1 - 4 - 0  2020
# 25  4 - 2 - 0   0.667   7 - 5 - 0    0.583  4 - 0 - 0   5W  5 - 0 - 0  2020
# 26  3 - 3 - 0   0.500   7 - 5 - 0    0.583  4 - 0 - 0   1W  3 - 2 - 0  2020
# 27  1 - 5 - 0   0.167   4 - 8 - 0    0.333  0 - 3 - 1   1L  2 - 3 - 0  2020
# 28  4 - 2 - 0   0.667  10 - 2 - 0    0.833  4 - 0 - 0   1L  4 - 1 - 0  2020
# 29  4 - 2 - 0   0.667   6 - 6 - 0    0.500  2 - 2 - 0   1W  2 - 3 - 0  2020
# 30  3 - 3 - 0   0.500   6 - 6 - 0    0.500  1 - 3 - 0   4W  4 - 1 - 0  2020
# 31  1 - 5 - 0   0.167   4 - 8 - 0    0.333  1 - 3 - 0   3L  1 - 4 - 0  2020

# %%
# Cleaning up column names
teamRecorddf = teamRecorddf.rename(columns=str.lower)
teamRecorddf = teamRecorddf.rename(columns = {'last 5' : 'last_five'})

teamRecorddf.to_csv(r'teamRecord.csv', header=True, index=False)
